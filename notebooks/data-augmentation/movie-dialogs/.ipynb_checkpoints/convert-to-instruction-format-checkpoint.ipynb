# %% [markdown]
# ## Imports

# %%
from datasets import load_dataset
import numpy as np
import json

# %% [markdown]
# ## Dialog templates
# Templates for converting dialogs to prompts

# %%
DIALOG_TEMPLATES = {
    
### template for 4+ line dialogs
    "four_more_lines" : [
"""
Here's a {template} between {char1} and {char2} in a scene from a {genre} movie
    {dialogue1}
User : Can you continue the {template}
Assistant : Sure, the next dialogue for this scene could be
    {dialogue2}
 """,
    
"""
    {dialogue1}
User : Can you provide more dialog assuming {genre} movie
    {dialogue2}
""",
    
"""
I'm trying to complete the dialog for my characters {char1} and {char2}.Here's the {template}, Please help me complete it
    {dialogue1}
Assistant : Sure
    {dialogue2}
""",
    ],
    
## template for 2 line dialogs

    "two_lines" : [
"""
User : Assume {char1} and {char2} are characters from a {genre} movie, what would {char2} say if 
    {dialogue1}
Assistant : {char2} could say
    {dialogue2}
""",
],
    
## template for 3 line dialogs
    "three_lines" : [
"""
    {dialogue1}
User : provide a response assuming you're {char1}
Assistant : Sure
    {dialogue2}
""",
    
"""
    {dialogue1}
User : respond as {char1} to complete the conversation
Assistant : Sure
    {dialogue2}
""",
    ]
    
    
    
}

# %% [markdown]
# ## Code

# %%
def get_movie_dialogs():
    
    with open("/home/shahul/Data/movie_lines.txt",'rb') as f:
        movie_lines_data = [x.decode("latin").split("+++$+++") for x in f.readlines()]
    movie_dialog_dict = {}
    for dialog in movie_lines_data:
        movie_dialog_dict[dialog[0].strip()] = {"characterID":dialog[1].strip(),"characterName":dialog[3].strip(),'text':dialog[-1].strip()}
        
    return movie_dialog_dict

# %%
def get_dialogs(dialog_dict,start,end):
    
    dialog_list = []
    for idx in range(start,end+1):
        dialog_list.append(dialog_dict[f'L{idx}']['characterName']+": "+dialog_dict[f'L{idx}']['text'])
    num_lines = len(dialog_list)
    
    assert num_lines > 1, "Number of lines should be greater than one"
        
    if num_lines == 2:
        dialog1 = dialog_list[0]
        dialog2 = dialog_list[1]
    elif num_lines in (3,4):
        dialog1 = "\n    ".join(dialog_list[:2])
        dialog2 = "\n    ".join(dialog_list[2:])
    else:
        dialog_len = np.random.randint(2,(num_lines+1)//2)
        dialog1 = "\n    ".join(dialog_list[:dialog_len])
        dialog2 = "\n    ".join(dialog_list[dialog_len:])
    
    return dialog1,dialog2
    
    
def choose_prompt(num_lines):
        
        assert num_lines > 1, "Number of lines should be greater than one"
        
        if num_lines==2:
            prompt =  np.random.choice(DIALOG_TEMPLATES["two_lines"])
            
        elif num_lines == 3:
            prompt = np.random.choice(DIALOG_TEMPLATES["three_lines"])

        else:
            prompt = np.random.choice(DIALOG_TEMPLATES["four_more_lines"])
        
        
        return prompt
    

def convert_to_prompts(dataset,movie_dialog_dict):
    
    for i in range(200,220):
        data  = dataset['train'][i]

        lineids = [int(lineid[1:]) for lineid in data['utterance']['LineID']]
        num_lines = len(lineids)
        
        genre = "-".join(data['movieGenres'][:2])
        template = np.random.choice(['dialog','script','play'])
        char1 = movie_dialog_dict[f'L{lineids[0]}']['characterName']
        char2 = movie_dialog_dict[f'L{lineids[1]}']['characterName']
        dialogue1,dialogue2 = get_dialogs(movie_dialog_dict,lineids[0],lineids[-1])
        prompt = choose_prompt(num_lines)
        prompt = prompt.format(char1=char1, char2=char2, dialogue1=dialogue1, dialogue2=dialogue2, genre=genre, template=template)
        
        print("##")
        print(prompt)

# %%
movie_dialog_dict = get_movie_dialogs()
dataset = load_dataset("cornell_movie_dialog")
# Out:
# Found cached dataset cornell_movie_dialog (/home/shahul/.cache/huggingface/datasets/cornell_movie_dialog/default/0.1.0/b67b3433cf894b551cddcd82efdff0826f39b39a11d5c149e746a546a8dc85f3)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
convert_to_prompts(dataset,movie_dialog_dict)
# Out:
# ##
#
#     WALTER: What just happened?
#     SHARON: Your daughters went to the prom.
# User : Can you provide more dialog assuming comedy-romance movie
#     WALTER: Did I have anything to say about it?
#     SHARON: Absolutely not.
#     WALTER: That ' s what I thought
#
# ##
#
#     ALONSO: I never seen heat like this!  Not even in Las Minas!
#     SAILOR: The water's going putrid in the barrels.
# User : respond as ALONSO to complete the conversation
# Assistant : Sure
#     ALONSO: You'll be drinking your own piss... For the glory of Spain... and Admiral Colon...!  Bastard!
#
# ##
#
#     ALONSO: What are you listening to, chicken ass?
#     SAILOR: Ah, leave him alone.  He's doing no harm.
# User : respond as ALONSO to complete the conversation
# Assistant : Sure
#     ALONSO: With a face like that?  I don't want you looking at me.  You hear?
#
# ##
#
# User : Assume ALONSO and SAILOR are characters from a adventure-biography movie, what would SAILOR say if
#     ALONSO: He's the devil's child...
# Assistant : SAILOR could say
#     SAILOR: We'll all go crazy...
#
# ##
#
#     ALONSO: We should have seen land.
#     SAILOR: We left three weeks ago, Alonso. Can't be that near.
# User : provide a response assuming you're ALONSO
# Assistant : Sure
#     ALONSO: Can't be that far, I say.  Also, I don't like the smell of the sea around here.  Smells like a cunt. Bad sign...
#
# ##
#
#     AROJAZ: You say Asia can be found by sailing west?
#     COLUMBUS: Yes, your Eminence.  The voyage should not take more than six or seven weeks.
# User : Can you provide more dialog assuming adventure-biography movie
#     AROJAZ: Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?
#     COLUMBUS: I am, Your Eminence
#     AROJAZ: Then you cannot ignore that according to their calculations, the circumference of the Earth is approximately...  22,000 leagues or more.  Which makes the ocean... uncrossable.
#
# ##
#
# User : Assume AROJAZ and COLUMBUS are characters from a adventure-biography movie, what would COLUMBUS say if
#     AROJAZ: Senor Colon, an experienced captain such as yourself will understand our concern with the crew.  I am not willing to have on my conscience the loss of men who would have relied upon our judgment.
# Assistant : COLUMBUS could say
#     COLUMBUS: Excellency, you are right.
#
# ##
#
#     COLUMBUS: Your Eminence, there is only one way to settle the matter.  And that is to make the journey.  I am ready to risk my life to prove it possible.
#     AROJAZ: Your life, and that of others!
# User : respond as COLUMBUS to complete the conversation
# Assistant : Sure
#     COLUMBUS: If they agree to follow me, yes.
#
# ##
#
#     COLUMBUS: Trade, Your Excellency.  According to Marco Polo, the Kingdom of China is one of the richest of the world. Even the meanest buildings are roofed with gold.
#     AROJAZ: Is that all that interests you? Gold?
# User : provide a response assuming you're COLUMBUS
# Assistant : Sure
#     COLUMBUS: No.  The Portuguese have already discovered black-skinned people.  I, too, will find other populations -- and bring them to the word of God.
#
# ##
#
# User : Assume AROJAZ and COLUMBUS are characters from a adventure-biography movie, what would COLUMBUS say if
#     AROJAZ: If God intended our proximity to Asia, do you believe he would have waited for you to show it to the world?
# Assistant : COLUMBUS could say
#     COLUMBUS: Did He not choose a carpenter's son to reveal Himself to the world?
#
# ##
#
# User : Assume AROJAZ and COLUMBUS are characters from a adventure-biography movie, what would COLUMBUS say if
#     AROJAZ: Don't you realize your words could be considered heretical?
# Assistant : COLUMBUS could say
#     COLUMBUS: Blind faith is what I consider heresy!
#
# ##
#
# User : Assume COLUMBUS and AROJAZ are characters from a adventure-biography movie, what would AROJAZ say if
#     COLUMBUS: Asia can be found to the west -- and I will prove it.
# Assistant : AROJAZ could say
#     AROJAZ: IF-GOD-WILLS-IT!
#
# ##
#
#     SANCHEZ: The State has some reason to be interested in this man's proposition, Your Eminence...
#     AROJAZ: The Judgment is ours!
# User : provide a response assuming you're SANCHEZ
# Assistant : Sure
#     SANCHEZ: Naturally.  But I would really deplore the loss of such a potential opportunity for Spain for a... dispute over a point of geography.
#
# ##
#
# User : Assume AROJAZ and SANCHEZ are characters from a adventure-biography movie, what would SANCHEZ say if
#     AROJAZ: He is a mercenary!  Did he not already try to convince the King of Portugal of his absurd notions?
# Assistant : SANCHEZ could say
#     SANCHEZ: Indeed.  The world is full of mercenaries -- and states often make use of them, when it benefits them.  My only concern is the welfare and prosperity of Spain.
#
# ##
#
# User : Assume AROJAZ and SANCHEZ are characters from a adventure-biography movie, what would SANCHEZ say if
#     AROJAZ: It won't be easy to get rid of your prophet now, Don Sanchez.
# Assistant : SANCHEZ could say
#     SANCHEZ: On the contrary, Your Eminence.  It seems to me the man is preparing his own cross.
#
# ##
#
#     SANCHEZ: You can see for yourself.
#     AROJAZ: What a tragedy... what a waste of a life...
# User : respond as SANCHEZ to complete the conversation
# Assistant : Sure
#     SANCHEZ: A waste...?  Let me tell you something, Arojaz.  If your name, or mine, is ever remembered -- it will only be because of his.
#
# ##
#
# I'm trying to complete the dialog for my characters COLUMBUS and BEATRIX.Here's the script, Please help me complete it
#     COLUMBUS: I could be gone for years.
#     BEATRIX: I know.
# Assistant : Sure
#     COLUMBUS: I haven't given you much of a life.
#     BEATRIX: Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving...
#     COLUMBUS: Are we going to argue?
#     BEATRIX: I'd love to argue with you sometimes.  But you're never here!
#
# ##
#
# User : Assume COLUMBUS and BEATRIX are characters from a adventure-biography movie, what would BEATRIX say if
#     COLUMBUS: Perhaps I was never meant to live with a woman...
# Assistant : BEATRIX could say
#     BEATRIX: I find that hard to believe.
#
# ##
#
# User : Assume COLUMBUS and BEATRIX are characters from a adventure-biography movie, what would BEATRIX say if
#     COLUMBUS: She said yes.
# Assistant : BEATRIX could say
#     BEATRIX: Thank God...
#
# ##
#
#     BEATRIX: I'm not asking you to swear to anything.
#     COLUMBUS: I don't want you to wait for me.
# User : provide a response assuming you're BEATRIX
# Assistant : Sure
#     BEATRIX: That's something you can't decide.
